# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')

df = pd.read_csv('/content/drive/MyDrive/animal_reports.csv')

def convert_to_animal_reports(filepath, year):
  df = pd.read_csv(filepath)
  filtered_df = df[df['reason'] == 'Animal Issues']
  filtered_df.to_csv(f'AnimalReport{year}.csv', index=False)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
full_df = pd.read_csv('/content/drive/MyDrive/FullAnimalReports.csv')
# Out:
# <ipython-input-63-28f381ff3800>:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   full_df = pd.read_csv('/content/drive/MyDrive/FullAnimalReports.csv')

# %%
full_df.head()
# Out:
#    case_enquiry_id              open_dt sla_target_dt            closed_dt  \
# 0     101000947005  2013-10-15 13:52:13           NaN  2013-10-15 13:54:27
# 1     101000947051  2013-10-15 16:33:04           NaN                  NaN
# 2     101000947072  2013-10-15 17:55:04           NaN                  NaN
# 3     101000947105  2013-10-16 03:00:40           NaN                  NaN
# 4     101000947109  2013-10-16 03:04:26           NaN                  NaN
#
#   on_time case_status                  closure_reason              case_title  \
# 0  ONTIME      Closed  Case Closed Case Invalid test              Animal Lost
# 1  ONTIME        Open                                  Animal Generic Request
# 2  ONTIME        Open                                  Animal Generic Request
# 3  ONTIME        Open                                  Animal Generic Request
# 4  ONTIME        Open                                  Animal Generic Request
#
#           subject         reason  ...                            neighborhood  \
# 0  Animal Control  Animal Issues  ...                             Charlestown
# 1  Animal Control  Animal Issues  ...                              Roslindale
# 2  Animal Control  Animal Issues  ...  South Boston / South Boston Waterfront
# 3  Animal Control  Animal Issues  ...                              Dorchester
# 4  Animal Control  Animal Issues  ...  South Boston / South Boston Waterfront
#
#   neighborhood_services_district     ward  precinct location_street_name  \
# 0                              2   Ward 2      0201          100 Main St
# 1                             10  Ward 20      2008       73 Montvale St
# 2                              5   Ward 6      0604        372 Athens St
# 3                             13       12      1207   79-83 Hutchings St
# 4                              5   Ward 6      0604       506 E Broadway
#
#   location_zipcode   latitude  longitude  \
# 0           2129.0  42.373991 -71.063537
# 1           2131.0  42.284010 -71.143611
# 2           2127.0  42.336520 -71.046010
# 3           2121.0  42.311130 -71.090631
# 4           2127.0  42.335682 -71.044388
#
#                                            geom_4326            source
# 0  0101000020E61000006E0343FD10C451C0E6772EECDE2F...  Constituent Call
# 1  0101000020E6100000341260EB30C951C0E435956D5A24...  Constituent Call
# 2  0101000020E61000002949E3D5F1C251C009213712132B...  Constituent Call
# 3  0101000020E6100000974464E4CCC551C07D0DFC17D327...  Constituent Call
# 4  0101000020E610000091698B3FD7C251C07E66D69EF72A...  Constituent Call
#
# [5 rows x 30 columns]

# %%
filtered_full_df = full_df[["closure_reason" , "reason" , "location" ,"neighborhood", "neighborhood_services_district" , "ward" , "precinct" , "location_street_name", "location_zipcode", "latitude" , "longitude" ]]

# %%
filtered_full_df.head()
# Out:
#                    closure_reason         reason  \
# 0  Case Closed Case Invalid test   Animal Issues
# 1                                  Animal Issues
# 2                                  Animal Issues
# 3                                  Animal Issues
# 4                                  Animal Issues
#
#                                     location  \
# 0        100 Main St  Charlestown  MA  02129
# 1      73 Montvale St  Roslindale  MA  02131
# 2     372 Athens St  South Boston  MA  02127
# 3  79-83 Hutchings St  Dorchester  MA  02121
# 4    506 E Broadway  South Boston  MA  02127
#
#                              neighborhood neighborhood_services_district  \
# 0                             Charlestown                              2
# 1                              Roslindale                             10
# 2  South Boston / South Boston Waterfront                              5
# 3                              Dorchester                             13
# 4  South Boston / South Boston Waterfront                              5
#
#       ward precinct location_street_name  location_zipcode   latitude  \
# 0   Ward 2     0201          100 Main St            2129.0  42.373991
# 1  Ward 20     2008       73 Montvale St            2131.0  42.284010
# 2   Ward 6     0604        372 Athens St            2127.0  42.336520
# 3       12     1207   79-83 Hutchings St            2121.0  42.311130
# 4   Ward 6     0604       506 E Broadway            2127.0  42.335682
#
#    longitude
# 0 -71.063537
# 1 -71.143611
# 2 -71.046010
# 3 -71.090631
# 4 -71.044388

# %%
num_complaints = 0
for complaint in filtered_full_df["closure_reason"]:
  if complaint != " ":
    num_complaints += 1

# %%
print(f"this is the number of complaints : {num_complaints}")
# Out:
# this is the number of complaints : 16510

# %%
file_path = '/content/drive/MyDrive/animals.txt'

animals_lst = []

with open(file_path, 'r') as file:
    for line in file:
        animals_lst.append(line.strip().lower())
print(animals_lst)
# Out:
# ['canidae', 'felidae', 'cat', 'cattle', 'dog', 'donkey', 'goat', 'guinea pig', 'horse', 'pig', 'rabbit', 'fancy rat varieties', 'laboratory rat strains', 'sheep breeds', 'water buffalo breeds', 'chicken breeds', 'duck breeds', 'goose breeds', 'pigeon breeds', 'turkey breeds', 'aardvark', 'aardwolf', 'african buffalo', 'african elephant', 'african leopard', 'albatross', 'alligator', 'alpaca', 'american buffalo (bison)', 'american robin', 'amphibian', 'list', 'anaconda', 'angelfish', 'anglerfish', 'ant', 'anteater', 'antelope', 'antlion', 'ape', 'aphid', 'arabian leopard', 'arctic fox', 'arctic wolf', 'armadillo', 'arrow crab', 'asp', 'ass (donkey)', 'baboon', 'badger', 'bald eagle', 'bandicoot', 'barnacle', 'barracuda', 'basilisk', 'bass', 'bat', 'beaked whale', 'bear', 'list', 'beaver', 'bedbug', 'bee', 'beetle', 'bird', 'list', 'bison', 'blackbird', 'black panther', 'black widow spider', 'blue bird', 'blue jay', 'blue whale', 'boa', 'boar', 'bobcat', 'bobolink', 'bonobo', 'booby', 'box jellyfish', 'bovid', 'buffalo, african', 'buffalo, american (bison)', 'bug', 'butterfly', 'buzzard', 'camel', 'canid', 'cape buffalo', 'capybara', 'cardinal', 'caribou', 'carp', 'cat', 'list', 'catshark', 'caterpillar', 'catfish', 'cattle', 'list', 'centipede', 'cephalopod', 'chameleon', 'cheetah', 'chickadee', 'chicken', 'list', 'chimpanzee', 'chinchilla', 'chipmunk', 'clam', 'clownfish', 'cobra', 'cockroach', 'cod', 'condor', 'constrictor', 'coral', 'cougar', 'cow', 'coyote', 'crab', 'crane', 'crane fly', 'crawdad', 'crayfish', 'cricket', 'crocodile', 'crow', 'cuckoo', 'cicada', 'damselfly', 'deer', 'dingo', 'dinosaur', 'list', 'dog', 'list', 'dolphin', 'donkey', 'list', 'dormouse', 'dove', 'dragonfly', 'dragon', 'duck', 'list', 'dung beetle', 'eagle', 'earthworm', 'earwig', 'echidna', 'eel', 'egret', 'elephant', 'elephant seal', 'elk', 'emu', 'english pointer', 'ermine', 'falcon', 'ferret', 'finch', 'firefly', 'fish', 'flamingo', 'flea', 'fly', 'flyingfish', 'fowl', 'fox', 'frog', 'fruit bat', 'gamefowl', 'list', 'galliform', 'list', 'gazelle', 'gecko', 'gerbil', 'giant panda', 'giant squid', 'gibbon', 'gila monster', 'giraffe', 'goat', 'list', 'goldfish', 'goose', 'list', 'gopher', 'gorilla', 'grasshopper', 'great blue heron', 'great white shark', 'grizzly bear', 'ground shark', 'ground sloth', 'grouse', 'guan', 'list', 'guanaco', 'guineafowl', 'list', 'guinea pig', 'list', 'gull', 'guppy', 'haddock', 'halibut', 'hammerhead shark', 'hamster', 'hare', 'harrier', 'hawk', 'hedgehog', 'hermit crab', 'heron', 'herring', 'hippopotamus', 'hookworm', 'hornet', 'horse', 'list', 'hoverfly', 'hummingbird', 'humpback whale', 'hyena', 'iguana', 'impala', 'irukandji jellyfish', 'jackal', 'jaguar', 'jay', 'jellyfish', 'junglefowl', 'kangaroo', 'kangaroo mouse', 'kangaroo rat', 'kingfisher', 'kite', 'kiwi', 'koala', 'koi', 'komodo dragon', 'krill', 'ladybug', 'lamprey', 'landfowl', 'land snail', 'lark', 'leech', 'lemming', 'lemur', 'leopard', 'leopon', 'limpet', 'lion', 'lizard', 'llama', 'lobster', 'locust', 'loon', 'louse', 'lungfish', 'lynx', 'macaw', 'mackerel', 'magpie', 'mammal', 'manatee', 'mandrill', 'manta ray', 'marlin', 'marmoset', 'marmot', 'marsupial', 'marten', 'mastodon', 'meadowlark', 'meerkat', 'mink', 'minnow', 'mite', 'mockingbird', 'mole', 'mollusk', 'mongoose', 'monitor lizard', 'monkey', 'moose', 'mosquito', 'moth', 'mountain goat', 'mouse', 'mule', 'muskox', 'narwhal', 'newt', 'new world quail', 'nightingale', 'ocelot', 'octopus', 'old world quail', 'opossum', 'orangutan', 'orca', 'ostrich', 'otter', 'owl', 'ox', 'panda', 'panther', 'panthera hybrid', 'parakeet', 'parrot', 'parrotfish', 'partridge', 'peacock', 'peafowl', 'pelican', 'penguin', 'perch', 'peregrine falcon', 'pheasant', 'pig', 'pigeon', 'list', 'pike', 'pilot whale', 'pinniped', 'piranha', 'planarian', 'platypus', 'polar bear', 'pony', 'porcupine', 'porpoise', "portuguese man o' war", 'possum', 'prairie dog', 'prawn', 'praying mantis', 'primate', 'ptarmigan', 'puffin', ' ...

# %%
animal_frequency = {}

# %%
# assign list
l = animals_lst

print("the" in animals_lst)
# Out:
# False

# %%
for complaint in filtered_full_df["closure_reason"]:
  for word in complaint.split():
    if complaint != " ":
      if (word in animals_lst):
        if word not in animal_frequency:
          animal_frequency[word] = 1
        else:
          animal_frequency[word] += 1

# %%
print(animal_frequency)
# Out:
# {'dog': 3454, 'squirrel': 255, 'cat': 854, 'bird': 745, 'bat': 359, 'raccoon': 455, 'rat': 14, 'deer': 34, 'possum': 19, 'rabbit': 283, 'crow': 10, 'fly': 49, 'skunk': 152, 'hawk': 126, 'chicken': 10, 'goose': 165, 'coyote': 73, 'opossum': 50, 'turkey': 105, 'duck': 41, 'beaver': 3, 'turtle': 14, 'owl': 15, 'snake': 31, 'pigeon': 100, 'gull': 71, 'ferret': 11, 'dragon': 1, 'swan': 21, 'sparrow': 5, 'dove': 17, 'rodent': 7, 'fish': 2, 'rooster': 9, 'hamster': 1, 'mouse': 4, 'falcon': 4, 'cardinal': 1, 'parakeet': 10, 'raven': 1, 'jay': 4, 'fox': 5, 'quail': 1, 'peacock': 3, 'fowl': 3, 'pig': 7, 'frog': 1, 'bear': 1, 'tern': 1, 'chipmunk': 2, 'lizard': 1, 'parrot': 1, 'python': 1, 'chinchilla': 1, 'sheep': 1}

# %%
full_df_animals = pd.read_csv('/content/drive/MyDrive/FullAnimalReports.csv')
full_df_animals = full_df[["closure_reason" , "reason" , "location" ,"neighborhood", "neighborhood_services_district" , "ward" , "precinct" , "location_street_name", "location_zipcode", "latitude" , "longitude" ]]
# Out:
# <ipython-input-74-4b206eeabd7f>:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   full_df_animals = pd.read_csv('/content/drive/MyDrive/FullAnimalReports.csv')

# %%
full_df_animals.head()
# Out:
#                    closure_reason         reason  \
# 0  Case Closed Case Invalid test   Animal Issues
# 1                                  Animal Issues
# 2                                  Animal Issues
# 3                                  Animal Issues
# 4                                  Animal Issues
#
#                                     location  \
# 0        100 Main St  Charlestown  MA  02129
# 1      73 Montvale St  Roslindale  MA  02131
# 2     372 Athens St  South Boston  MA  02127
# 3  79-83 Hutchings St  Dorchester  MA  02121
# 4    506 E Broadway  South Boston  MA  02127
#
#                              neighborhood neighborhood_services_district  \
# 0                             Charlestown                              2
# 1                              Roslindale                             10
# 2  South Boston / South Boston Waterfront                              5
# 3                              Dorchester                             13
# 4  South Boston / South Boston Waterfront                              5
#
#       ward precinct location_street_name  location_zipcode   latitude  \
# 0   Ward 2     0201          100 Main St            2129.0  42.373991
# 1  Ward 20     2008       73 Montvale St            2131.0  42.284010
# 2   Ward 6     0604        372 Athens St            2127.0  42.336520
# 3       12     1207   79-83 Hutchings St            2121.0  42.311130
# 4   Ward 6     0604       506 E Broadway            2127.0  42.335682
#
#    longitude
# 0 -71.063537
# 1 -71.143611
# 2 -71.046010
# 3 -71.090631
# 4 -71.044388

# %%
sorted_animal_frequency = sorted(animal_frequency, key=animal_frequency.get, reverse=True)


print(sorted_animal_frequency)
# Out:
# ['dog', 'cat', 'bird', 'raccoon', 'bat', 'rabbit', 'squirrel', 'goose', 'skunk', 'hawk', 'turkey', 'pigeon', 'coyote', 'gull', 'opossum', 'fly', 'duck', 'deer', 'snake', 'swan', 'possum', 'dove', 'owl', 'rat', 'turtle', 'ferret', 'crow', 'chicken', 'parakeet', 'rooster', 'rodent', 'pig', 'sparrow', 'fox', 'mouse', 'falcon', 'jay', 'beaver', 'peacock', 'fowl', 'fish', 'chipmunk', 'dragon', 'hamster', 'cardinal', 'raven', 'quail', 'frog', 'bear', 'tern', 'lizard', 'parrot', 'python', 'chinchilla', 'sheep']

# %%
df_animal_lat_long = pd.read_csv("/content/df_animal_lat_long.csv")

dog_df = df_animal_lat_long[df_animal_lat_long['Animal'] == 'dog']
cat_df = df_animal_lat_long[df_animal_lat_long['Animal'] == 'cat']
bird_df = df_animal_lat_long[df_animal_lat_long['Animal'] == 'bird']
raccoon_df = df_animal_lat_long[df_animal_lat_long['Animal'] == 'raccoon']
bat_df = df_animal_lat_long[df_animal_lat_long['Animal'] == 'bat']

dog_df.to_csv(f'dog_lat_long.csv', index=False)
cat_df.to_csv(f'cat_lat_long.csv', index=False)
bird_df.to_csv(f'bird_lat_long.csv', index=False)
raccoon_df.to_csv(f'raccoon_lat_long.csv', index=False)
bat_df.to_csv(f'bat_lat_long.csv', index=False)

# %%
animal_frequency

keysList = list(animal_frequency.keys())
valsList = list(animal_frequency.values())

print(keysList)
print(valsList)
# Out:
# ['dog', 'squirrel', 'cat', 'bird', 'bat', 'raccoon', 'rat', 'deer', 'possum', 'rabbit', 'crow', 'fly', 'skunk', 'hawk', 'chicken', 'goose', 'coyote', 'opossum', 'turkey', 'duck', 'beaver', 'turtle', 'owl', 'snake', 'pigeon', 'gull', 'ferret', 'dragon', 'swan', 'sparrow', 'dove', 'rodent', 'fish', 'rooster', 'hamster', 'mouse', 'falcon', 'cardinal', 'parakeet', 'raven', 'jay', 'fox', 'quail', 'peacock', 'fowl', 'pig', 'frog', 'bear', 'tern', 'chipmunk', 'lizard', 'parrot', 'python', 'chinchilla', 'sheep']
# [3454, 255, 854, 745, 359, 455, 14, 34, 19, 283, 10, 49, 152, 126, 10, 165, 73, 50, 105, 41, 3, 14, 15, 31, 100, 71, 11, 1, 21, 5, 17, 7, 2, 9, 1, 4, 4, 1, 10, 1, 4, 5, 1, 3, 3, 7, 1, 1, 1, 2, 1, 1, 1, 1, 1]

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

animals = keysList
counts = valsList
bar_labels = ['red', 'blue', '_red', 'orange']
bar_colors = ['tab:red', 'tab:blue', 'tab:red', 'tab:orange']

ax.bar(animals, counts)

ax.set_ylabel('Number of Reports')
ax.set_title('Numbers of Reports by Each Animal 2013-Present')

# Adjusting the width of the x-axis
fig.set_size_inches(20, 6)  # Set width to 20 inches and height to 6 inches
ax.set_xticklabels(animals, rotation=90, ha='center')
plt.show()
# Out:
# <ipython-input-95-455573457d00>:17: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(animals, rotation=90, ha='center')

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('/content/drive/MyDrive/FullAnimalReports.csv')
df = df.rename(columns={'open_dt': "datetime"})
df["datetime"] = pd.to_datetime(df["datetime"])
df["month"] = df["datetime"].dt.month

fig, axs = plt.subplots(figsize=(12, 4))
df.groupby(df["datetime"].dt.year)['closure_reason'].count().plot( kind='bar', rot=0, ax=axs )
plt.xlabel("Per year")
plt.ylabel("count")

fig, axs = plt.subplots(figsize=(12, 4))
df.groupby(df["datetime"].dt.month)['closure_reason'].count().plot( kind='bar', rot=0, ax=axs )
plt.xlabel("Per month")
plt.ylabel("count")

fig, axs = plt.subplots(figsize=(12, 4))
df.groupby(df["datetime"].dt.hour)['closure_reason'].count().plot( kind='bar', rot=0, ax=axs )
plt.xlabel("Per hour")
plt.ylabel("count")
# Out:
# <ipython-input-4-efb38bde3e9b>:3: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/drive/MyDrive/FullAnimalReports.csv')
# Text(0, 0.5, 'count')
