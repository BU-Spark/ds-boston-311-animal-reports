# %%
import pandas as pd

#csv with only animal data
df = pd.read_csv('2011_2024.csv')
# Out:
# /var/folders/mf/txv8p7fx2yz68v4bx9pfbxf80000gn/T/ipykernel_90456/3676657450.py:4: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('2011_2024.csv')

# %%
df.head()
# Out:
#    _id  case_enquiry_id              open_dt        sla_target_dt  \
# 0    9     101000295622  2011-07-01 02:44:50  2011-07-04 02:44:49
# 1   21     101000295636  2011-07-01 03:44:54  2011-07-04 03:44:53
# 2   98     101000295715  2011-07-01 04:40:53  2011-07-04 04:40:53
# 3  225     101000295859  2011-07-01 06:51:01  2011-07-04 06:51:00
# 4  264     101000295903  2011-07-01 07:46:49  2011-07-04 07:46:45
#
#              closed_dt on_time case_status  \
# 0  2011-07-01 02:44:55  ONTIME      Closed
# 1  2011-07-01 05:19:44  ONTIME      Closed
# 2  2011-07-01 05:18:50  ONTIME      Closed
# 3  2011-07-01 06:51:08  ONTIME      Closed
# 4  2011-07-01 09:15:33  ONTIME      Closed
#
#                                       closure_reason           case_title  \
# 0                         Case Closed Internal Case   Pick up Dead Animal
# 1  Case Closed Case Resolved Pickup Dead Animal (...  Pick up Dead Animal
# 2                         Case Closed Case Resolved   Pick up Dead Animal
# 3                         Case Closed Internal Case   Pick up Dead Animal
# 4               Case Closed Case Resolved picked up   Pick up Dead Animal
#
#                    subject  ...      neighborhood  \
# 0  Public Works Department  ...        Dorchester
# 1  Public Works Department  ...  Greater Mattapan
# 2  Public Works Department  ...       Charlestown
# 3  Public Works Department  ...        Dorchester
# 4  Public Works Department  ...         Hyde Park
#
#   neighborhood_services_district     ward precinct location_street_name  \
# 0                              7  Ward 16     1602      305 Freeport St
# 1                              9  Ward 18     1801     10 Ledgebrook Rd
# 2                              2   Ward 2     0202     114 Sixteenth St
# 3                              8  Ward 15     1504         10 Hendry St
# 4                             10  Ward 18     1813        69 Davison St
#
#   location_zipcode   latitude  longitude  \
# 0           2122.0  42.302020 -71.051911
# 1           2126.0  42.270690 -71.083371
# 2           2129.0  42.379345 -71.051074
# 3           2125.0  42.308970 -71.064861
# 4           2136.0  42.257640 -71.117461
#
#                                            geom_4326              source
# 0  0101000020E6100000AC4EA98052C351C098735293A826...  Employee Generated
# 1  0101000020E61000009AEA0EF255C551C0821CA0F4A522...    Constituent Call
# 2  0101000020E6100000EA197ECD44C351C06EBE625C8E30...    Constituent Call
# 3  0101000020E61000004562F4AC26C451C0B1264B508C27...  Employee Generated
# 4  0101000020E6100000F91C537A84C751C0FE88B655FA20...  Employee Generated
#
# [5 rows x 31 columns]

# %%
#print(df.columns)
#print(df.head(10))
df_longitudinal = df[['latitude', 'longitude']]
df_longitudinal
df_longitudinal = df_longitudinal.dropna()

# %%
df['open_dt'].head()
# Out:
# 0    2011-07-01 02:44:50
# 1    2011-07-01 03:44:54
# 2    2011-07-01 04:40:53
# 3    2011-07-01 06:51:01
# 4    2011-07-01 07:46:49
# Name: open_dt, dtype: object

# %%
import matplotlib.pyplot as plt
import pandas as pd
import os

# Assuming df is your DataFrame with 'open_dt', 'longitude', and 'latitude' columns

# Convert 'open_dt' column to datetime type if it's not already
df['open_dt'] = pd.to_datetime(df['open_dt'])

# Create a directory to store the images
output_dir = 'plots'
os.makedirs(output_dir, exist_ok=True)

# Loop through each day from 2011 to 2012
start_date = pd.to_datetime('2011-7-01')
end_date = pd.to_datetime('2012-12-31')
for single_date in pd.date_range(start_date, end_date):
    # Filter DataFrame for the specific date
    df_specific_date = df[df['open_dt'].dt.date == single_date.date()]

    # Plot the points for the specific date
    plt.scatter(df_specific_date['longitude'], df_specific_date['latitude'])
    plt.xlabel('Longitude')
    plt.ylabel('Latitude')
    plt.title(f'Map of Points - {single_date.strftime("%Y-%m-%d")}')
    
    # Save the plot as an image
    plt.savefig(f'{output_dir}/{single_date.strftime("%Y-%m-%d")}.png')
    plt.close()

# Convert images to a GIF
import imageio
images = []
for filename in sorted(os.listdir(output_dir)):
    if filename.endswith('.png'):
        images.append(imageio.imread(os.path.join(output_dir, filename)))
imageio.mimsave('map_animation.gif', images, fps=5)

# Remove the temporary image files
import shutil
shutil.rmtree(output_dir)

print("GIF created successfully.")
# Out:
# /var/folders/mf/txv8p7fx2yz68v4bx9pfbxf80000gn/T/ipykernel_90456/1307015802.py:36: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning dissapear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   images.append(imageio.imread(os.path.join(output_dir, filename)))
# GIF created successfully.

# %%
df = pd.read_csv('2011_2024.csv')
df['open_dt'] = pd.to_datetime(df['open_dt'])
# Out:
# /var/folders/mf/txv8p7fx2yz68v4bx9pfbxf80000gn/T/ipykernel_92406/690691600.py:1: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('2011_2024.csv')

# %%
import os
import time
from datetime import datetime
from selenium import webdriver
import imageio
from PIL import Image, ImageDraw, ImageFont
import folium
from folium.plugins import HeatMap
import pandas as pd
from bs4 import BeautifulSoup

def add_text_to_image(image_filename, text):
    # Load the image
    base_image = Image.open(image_filename)

    # Get the dimensions of the base image
    base_width, base_height = base_image.size

    # Create a new image with white background
    text_image = Image.new("RGB", (base_width, 100), "white")

    # Set up font properties
    font = ImageFont.truetype("/System/Library/Fonts/Supplemental/arial.ttf", 50)

    # Calculate text size and position
    draw = ImageDraw.Draw(text_image)
    text_bbox = draw.textbbox((0, 0), text, font=font)
    text_x = (base_width - text_bbox[2]) // 2
    text_y = (100 - text_bbox[3]) // 2

    # Draw the text on the image
    draw.text((text_x, text_y), text, fill="black", font=font)

    # Combine the two images
    combined_image = Image.new("RGB", (base_width, base_height + 100))
    combined_image.paste(base_image, (0, 0))
    combined_image.paste(text_image, (0, base_height))

    # Save the combined image
    combined_image.save(image_filename)

def modify_zoom_level(html_file):
    with open(html_file, 'r') as file:
        html_content = file.read()

    soup = BeautifulSoup(html_content, 'html.parser')

    # Find the script tag containing the zoom level
    script_tag = soup.find('script', string=lambda text: 'zoom' in str(text))

    if script_tag:
        # Extracting the script content
        script_content = script_tag.string.strip()

        # Replacing the zoom level from 10 to 12
        script_content = script_content.replace('zoom: 10', 'zoom: 12')

        # Update the script content
        script_tag.string.replace_with(script_content)

        # Write the modified HTML back to the file
        with open(html_file, 'w') as file:
            file.write(str(soup))

# Directory containing the HTML files
html_dir = 'maps'

# Create a directory to store the HTML files
os.makedirs(html_dir, exist_ok=True)

# Load DataFrame with latitude and longitude columns
# Assuming df is your DataFrame with 'latitude' and 'longitude' columns
# Drop rows with NaN values in latitude or longitude columns
df_cleaned = df.dropna(subset=['latitude', 'longitude'])

# Loop through each year from 2013 to 2023
for year in range(2013, 2024):
    # Create a directory to store images for this year
    year_image_dir = os.path.join(html_dir, str(year))
    os.makedirs(year_image_dir, exist_ok=True)

    # Loop through each month
    for month in range(1, 13):
        # Filter DataFrame for the specific year and month
        df_specific_month = df_cleaned[(df_cleaned['open_dt'].dt.year == year) & (df_cleaned['open_dt'].dt.month == month)]

        # Create a map object
        m = folium.Map(location=[df_specific_month['latitude'].mean(), df_specific_month['longitude'].mean()], zoom_start=10)

        # Add heatmap layer to the map
        heat_data = [[row['latitude'], row['longitude']] for _, row in df_specific_month.iterrows()]
        HeatMap(heat_data).add_to(m)

        # Save the map as an HTML file
        file_name = os.path.join(year_image_dir, f'{year}-{month:02}.html')
        m.save(file_name)

        # Modify zoom level in the HTML file
        modify_zoom_level(file_name)

# Directory to save GIFs
gif_dir = 'gif'
os.makedirs(gif_dir, exist_ok=True)

# Loop through each year and create GIF
for year in range(2013, 2024):
    # Directory to save image files
    year_image_dir = os.path.join(html_dir, str(year))

    # List to store image paths
    image_paths = []

    # Configure Selenium webdriver
    options = webdriver.ChromeOptions()
    options.add_argument('--no-sandbox')
    options.add_argument('--disable-dev-shm-usage')
    options.add_argument('--headless')
    driver = webdriver.Chrome(options=options)

    # Loop through HTML files and capture screenshots
    for filename in sorted(os.listdir(year_image_dir)):
        if filename.endswith('.html'):
            html_file = os.path.abspath(os.path.join(year_image_dir, filename))

            # Open HTML file in headless Chrome and adjust zoom level
            driver.get(f'file://{html_file}')
            time.sleep(2)  # Wait for the page to load

            # Capture screenshot
            screenshot = driver.get_screenshot_as_png()

            # Save screenshot as PNG
            image_file = os.path.join(year_image_dir, filename.replace('.html', '.png'))
            with open(image_file, 'wb') as f:
                f.write(screenshot)

            # Add filename (without extension) as text to image
            file_text = os.path.splitext(filename)[0]  # Extract filename without extension
            add_text_to_image(image_file, file_text)

            image_paths.append(image_file)

    # Convert screenshots to GIF
    images = [imageio.imread(image_path) for image_path in image_paths]
    gif_filename = os.path.join(gif_dir, f'{year}.gif')
    imageio.mimsave(gif_filename, images, fps=1)

    # Remove temporary image files
    for image_path in image_paths:
        os.remove(image_path)

    # Quit the webdriver
    driver.quit()

    print(f"GIF for year {year} created successfully.")

print("All GIFs created successfully.")
# Out:
# /var/folders/mf/txv8p7fx2yz68v4bx9pfbxf80000gn/T/ipykernel_92406/4287692058.py:144: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning dissapear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   images = [imageio.imread(image_path) for image_path in image_paths]
# GIF for year 2013 created successfully.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/mf/txv8p7fx2yz68v4bx9pfbxf80000gn/T/ipykernel_92406/4287692058.py in <module>
#     128
#     129             # Capture screenshot
# --> 130             screenshot = driver.get_screenshot_as_png()
#     131
#     132             # Save screenshot as PNG
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in get_screenshot_as_png(self)
#     830                 driver.get_screenshot_as_png()
#     831         """
# --> 832         return b64decode(self.get_screenshot_as_base64().encode("ascii"))
#     833
#     834     def get_screenshot_as_base64(self) -> str:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in get_screenshot_as_base64(self)
#     841                 driver.get_screenshot_as_base64()
#     842         """
# --> 843         return self.execute(Command.SCREENSHOT)["value"]
#     844
#     845     def set_window_size(self, width, height, windowHandle: str = "current") -> None:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     343                 params["sessionId"] = self.session_id
#     344
# --> 345         response = self.command_executor.execute(driver_command, params)
#     346         if response:
#     347             self.error_handler.check_response(response)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     300         trimmed = self._trim_large_entries(params)
#     301         LOGGER.debug("%s %s %s", command_info[0], url, str(trimmed))
# --> 302         return self._request(command_info[0], url, body=data)
#     303
#     304     def _request(self, method, url, body=None):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     320
#     321         if self.keep_alive:
# --> 322             response = self._conn.request(method, url, body=body, headers=headers)
#     323             statuscode = response.status
#     324         else:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      72
#      73         if method in self._encode_url_methods:
# ---> 74             return self.request_encode_url(
#      75                 method, url, fields=fields, headers=headers, **urlopen_kw
#      76             )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/request.py in request_encode_url(self, method, url, fields, headers, **urlopen_kw)
#      94             url += "?" + urlencode(fields)
#      95
# ---> 96         return self.urlopen(method, url, **extra_kw)
#      97
#      98     def request_encode_body(
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     374             response = conn.urlopen(method, url, **kw)
#     375         else:
# --> 376             response = conn.urlopen(method, u.request_uri, **kw)
#     377
#     378         redirect_location = redirect and response.get_redirect_location()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     701
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#     705                 method,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     447                     # Python 3 (including for exceptions like SystemExit).
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     442                 # Python 3
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#     446                     # Remove the TypeError from the exception chain in
#
# ~/opt/anaconda3/lib/python3.9/http/client.py in getresponse(self)
#    1375         try:
#    1376             try:
# -> 1377                 response.begin()
#    1378             except ConnectionError:
#    1379                 self.close()
#
# ~/opt/anaconda3/lib/python3.9/http/client.py in begin(self)
#     318         # read until we get a non-100 response
#     319         while True:
# --> 320             version, status, reason = self._read_status()
#     321             if status != CONTINUE:
#     322                 break
#
# ~/opt/anaconda3/lib/python3.9/http/client.py in _read_status(self)
#     279
#     280     def _read_status(self):
# --> 281         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282         if len(line) > _MAXLINE:
#     283             raise LineTooLong("status line")
#
# ~/opt/anaconda3/lib/python3.9/socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
# Out:
# Modified zoom level in 2013-01.html
# Modified zoom level in 2012-01.html
# Modified zoom level in 2013-11.html
# Modified zoom level in 2013-07.html
# Modified zoom level in 2012-06.html
# Modified zoom level in 2012-10.html
# Modified zoom level in 2012-11.html
# Modified zoom level in 2012-07.html
# Modified zoom level in 2013-06.html
# Modified zoom level in 2013-10.html
# Modified zoom level in 2012-12.html
# Modified zoom level in 2012-04.html
# Modified zoom level in 2013-05.html
# Modified zoom level in 2012-08.html
# Modified zoom level in 2013-09.html
# Modified zoom level in 2013-08.html
# Modified zoom level in 2012-09.html
# Modified zoom level in 2013-12.html
# Modified zoom level in 2013-04.html
# Modified zoom level in 2012-05.html
# Modified zoom level in 2012-02.html
# Modified zoom level in 2013-03.html
# Modified zoom level in 2013-02.html
# Modified zoom level in 2012-03.html

# %%
# Out:
# /var/folders/mf/txv8p7fx2yz68v4bx9pfbxf80000gn/T/ipykernel_90456/3578080528.py:78: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning dissapear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   images = [imageio.imread(image_path) for image_path in image_paths]
# GIF created successfully.
