# %% [markdown]
# Let us first open the most recent .csv file we have for an initial Data Exploratory Analysis

# %%
import pandas as pd
# Out:
# /Users/themistoklis/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /Users/themistoklis/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.4' currently installed).
#   from pandas.core import (

# %%
df = pd.read_csv('Datasets/Analyze Boston/Boston_311_service_request_2023.csv')
df.head()
# Out:
# /var/folders/qf/yh559xpx4dv12z0mkyw5cvr80000gn/T/ipykernel_5231/3957751838.py:1: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Datasets/Analyze Boston/Boston_311_service_request_2023.csv')
#    case_enquiry_id              open_dt        sla_target_dt  \
# 0     101005184758  2023-11-30 09:17:00  2023-12-01 09:17:52
# 1     101005187668  2023-12-02 17:53:40  2023-12-05 03:30:00
# 2     101005184751  2023-11-30 09:12:55  2023-12-01 09:12:57
# 3     101005187656  2023-12-02 17:06:00  2023-12-11 03:30:00
# 4     101005184769  2023-11-30 09:23:00                  NaN
#
#              closed_dt  on_time case_status  \
# 0  2023-11-30 23:34:48   ONTIME      Closed
# 1  2023-12-03 04:26:55   ONTIME      Closed
# 2  2023-11-30 09:33:07   ONTIME      Closed
# 3                  NaN  OVERDUE        Open
# 4  2023-12-19 11:15:33   ONTIME      Closed
#
#                                       closure_reason  \
# ...

# %%
print(df.shape)
# Out:
# (313226, 30)

# %%
print(df.columns)
# Out:
# Index(['case_enquiry_id', 'open_dt', 'sla_target_dt', 'closed_dt', 'on_time',
#        'case_status', 'closure_reason', 'case_title', 'subject', 'reason',
#        'type', 'queue', 'department', 'submitted_photo', 'closed_photo',
#        'location', 'fire_district', 'pwd_district', 'city_council_district',
#        'police_district', 'neighborhood', 'neighborhood_services_district',
#        'ward', 'precinct', 'location_street_name', 'location_zipcode',
#        'latitude', 'longitude', 'geom_4326', 'source'],
#       dtype='object')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 313226 entries, 0 to 313225
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   case_enquiry_id                 313226 non-null  int64
#  1   open_dt                         313226 non-null  object
#  2   sla_target_dt                   247251 non-null  object
#  3   closed_dt                       283359 non-null  object
#  4   on_time                         313226 non-null  object
#  5   case_status                     313226 non-null  object
#  6   closure_reason                  313226 non-null  object
#  7   case_title                      313226 non-null  object
#  8   subject                         313226 non-null  object
#  9   reason                          313226 non-null  object
#  10  type                            313226 non-null  object
#  11  queue                           313226 non-null  object
# ...

# %%
df.describe(include='all')
# Out:
#         case_enquiry_id              open_dt        sla_target_dt  \
# count      3.132260e+05               313226               247251
# unique              NaN               273520               132079
# top                 NaN  2023-08-21 12:16:31  2023-09-06 04:30:00
# freq                NaN                   37                 2137
# mean       1.010049e+11                  NaN                  NaN
# std        1.763593e+05                  NaN                  NaN
# min        1.010046e+11                  NaN                  NaN
# 25%        1.010048e+11                  NaN                  NaN
# 50%        1.010049e+11                  NaN                  NaN
# 75%        1.010051e+11                  NaN                  NaN
# max        1.010052e+11                  NaN                  NaN
#
#                   closed_dt on_time case_status closure_reason  \
# count                283359  313226      313226         313226
# ...

# %% [markdown]
# All this information refer to every kind of request. Let us now filter out the irelevant requests.

# %%
#keep rows that have "animal" in the "case_title" column
df_filtered= df[df['case_title'].str.contains('animal', case=False)]
print("Out of ", df.shape[0], " requests, ", df_filtered.shape[0], " requests are related to animals")
# Out:
# Out of  313226  requests,  11011  requests are related to animals

# %%
df_filtered.head()
# Out:
#      case_enquiry_id              open_dt        sla_target_dt  \
# 13      101005187223  2023-12-02 07:57:00                  NaN
# 15      101005186086  2023-12-01 08:40:28  2023-12-04 08:40:29
# 110     101004971366  2023-08-06 10:53:00                  NaN
# 123     101004931303  2023-07-18 14:01:12  2023-07-20 04:30:00
# 129     101005033448  2023-09-04 08:46:57  2023-09-06 04:30:00
#
#                closed_dt on_time case_status  \
# 13   2023-12-04 04:13:13  ONTIME      Closed
# 15   2023-12-01 09:19:50  ONTIME      Closed
# 110                  NaN  ONTIME        Open
# 123  2023-07-18 16:11:21  ONTIME      Closed
# 129  2023-09-04 09:40:59  ONTIME      Closed
#
#                                         closure_reason  \
# 13   Case Closed. Closed date : 2023-12-04 09:13:13...
# 15   Case Closed. Closed date : Fri Dec 01 14:19:50...
# 110
# 123  Case Closed. Closed date : Tue Jul 18 20:11:21...
# 129  Case Closed. Closed date : Mon Sep 04 13:40:59...
#
# ...

# %%
df_filtered.describe(include='all')
# Out:
#         case_enquiry_id              open_dt        sla_target_dt  \
# count      1.101100e+04                11011                 6849
# unique              NaN                10935                 2871
# top                 NaN  2023-01-28 07:55:57  2023-09-06 04:30:00
# freq                NaN                    4                   85
# mean       1.010049e+11                  NaN                  NaN
# std        1.658530e+05                  NaN                  NaN
# min        1.010046e+11                  NaN                  NaN
# 25%        1.010048e+11                  NaN                  NaN
# 50%        1.010049e+11                  NaN                  NaN
# 75%        1.010051e+11                  NaN                  NaN
# max        1.010052e+11                  NaN                  NaN
#
#                   closed_dt on_time case_status closure_reason  \
# count                 10185   11011       11011          11011
# ...

# %% [markdown]
# With this initial insight, we can move onwards and apply the same for every year. We will first create a .csv file that only contains animal related requests and then perform our analysis.
