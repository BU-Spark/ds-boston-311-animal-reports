# %%
import glob
import pandas as pd
from collections import defaultdict
from matplotlib.patches import Patch
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm
# Out:
# /Users/themistoklis/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /Users/themistoklis/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.4' currently installed).
#   from pandas.core import (

# %% [markdown]
# From now on, we only focus on animal related requests. We have updated our data with an extra feature, the animal related to each request.

# %%
#read animal_cases.csv as df
df = pd.read_csv('../Datasets/animal_cases.csv')
# Out:
# /var/folders/qf/yh559xpx4dv12z0mkyw5cvr80000gn/T/ipykernel_6937/2066135082.py:2: DtypeWarning: Columns (13,16,18,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../Datasets/animal_cases.csv')

# %%
# if the 'animal' column has value 'Animal' make it nan
df['animal'] = df['animal'].apply(lambda x: np.nan if x == 'Animal' else x)
# if the 'animal' column is already nan, keep it nan
df['animal'] = df['animal'].apply(lambda x: np.nan if pd.isnull(x) else x)
# get the number of each distinct animal in the dataset
animal_requests = df['animal'].value_counts()
# sort the dict and plot it. add a line wit the average number of requests
sorted_animal_requests = dict(sorted(animal_requests.items(), key=lambda item: item[1], reverse=True))
plt.figure(figsize=(10, 6), dpi=80)
plt.bar(sorted_animal_requests.keys(), sorted_animal_requests.values(), color='b', alpha=0.7)
plt.axhline(y=np.mean(list(sorted_animal_requests.values())), color='r', linestyle='--', label='Average')
plt.xlabel('Animal')
plt.ylabel('Number of Requests')
plt.title('Number of Requests per Animal')
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %% [markdown]
# Displayed above is the distribution of various animals within the requests. As anticipated, household pets such as dogs and cats dominate the list, along with common city-dwellers like rats, birds, and squirrels, reflective of our locale in Boston.
#
# The first four animals dominate this plot, so lets remove them an re plot our data t oget a better insight on animals with less requests.

# %%
# from animal_requests, remove the keys that have value greater than 1000
animal_requests_filtered = {key: value for key, value in animal_requests.items() if value < 1000}
#sort the animal_requests_filtered dictionary by value
animal_requests_filtered = dict(sorted(animal_requests_filtered.items(), key=lambda item: item[1], reverse=True))
plt.figure(figsize=(10, 6), dpi=80)
plt.bar(animal_requests_filtered.keys(), animal_requests_filtered.values(), color='b', alpha=0.7)
plt.xlabel('Animal')
plt.ylabel('Number of Requests')
plt.title('Number of Requests per Animal')
plt.xticks(rotation=90)

plt.axhline(y=sum(animal_requests_filtered.values()) / len(animal_requests_filtered), color='r', linestyle='--', label='Average')
plt.legend()
plt.show()

# %% [markdown]
# In the previous plot, we abstractly removed every animal that has more than 1000 requests. However, a more accurate approach would be to use a logarithmic scale. This allows for a better representation of the data, especially when dealing with a wide range of values.

# %%
#take a log scale of the values
plt.figure(figsize=(10, 6), dpi=80)
plt.bar(sorted_animal_requests.keys(), np.log(list(sorted_animal_requests.values())), color='b', alpha=0.7)
plt.xlabel('Animal')
plt.ylabel('Log of Number of Requests')
plt.title('Log of Number of Requests per Animal')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Mid Semester Report

# %% [markdown]
# Let us also have a look at requests per neighborhood. First we will explore if there are requests with no neighborhood assigned.

# %%
print("Out of ", len(df), " requests, ", len(df[df['neighborhood'].isna()]) + len(df[df['neighborhood'] == ' ']), " do not have a neighborhood")
# make a copy of the dataframe and drop requests that do not have a neighborhood
df_neighborhood = df.dropna(subset=['neighborhood'])
df_neighborhood = df_neighborhood[df_neighborhood['neighborhood'] != ' ']
# Out:
# Out of  83281  requests,  263  do not have a neighborhood

# %%
#print distinct values of "neighborhood" column sorted by alphabetical order
sorted(df_neighborhood['neighborhood'].dropna().unique())
# Out:
# ['Allston',
#  'Allston / Brighton',
#  'Back Bay',
#  'Beacon Hill',
#  'Boston',
#  'Brighton',
#  'Charlestown',
#  'Chestnut Hill',
#  'Dorchester',
#  'Downtown / Financial District',
#  'East Boston',
#  'Fenway / Kenmore / Audubon Circle / Longwood',
#  'Greater Mattapan',
#  'Hyde Park',
#  'Jamaica Plain',
#  'Mattapan',
#  'Mission Hill',
#  'Roslindale',
#  'Roxbury',
#  'South Boston',
#  'South Boston / South Boston Waterfront',
#  'South End',
#  'West Roxbury']

# %%
#whenever there is "South" in the neighborhood, replace it with "S"
df_neighborhood['neighborhood'] = df_neighborhood['neighborhood'].apply(lambda x: x.replace('South', 'S.') if 'South' in x else x)
#whenever there is "North" in the neighborhood, replace it with "N"
df_neighborhood['neighborhood'] = df_neighborhood['neighborhood'].apply(lambda x: x.replace('North', 'N.') if 'North' in x else x)
#whenever there is "East" in the neighborhood, replace it with "E"
df_neighborhood['neighborhood'] = df_neighborhood['neighborhood'].apply(lambda x: x.replace('East', 'E.') if 'East' in x else x)
#whenever there is "West" in the neighborhood, replace it with "W"
df_neighborhood['neighborhood'] = df_neighborhood['neighborhood'].apply(lambda x: x.replace('West', 'W.') if 'West' in x else x)

# %% [markdown]
# We will now plot the distribution of requests per neighborhood.

# %%
#plot the number of requests per neighborhood
requests_per_neighborhood = df_neighborhood['neighborhood'].value_counts()
plt.figure(figsize=(10, 6), dpi=80)
plt.bar(requests_per_neighborhood.index, requests_per_neighborhood.values, color='b', alpha=0.7)
plt.xlabel('Neighborhood')
plt.ylabel('Number of Requests')
plt.title('Number of Requests per Neighborhood')
# make the labels of x ticks smaller
plt.xticks(rotation=90)
plt.show()

# %%
# heatmap of the number of requests per neighborhood and animal
requests_per_neighborhood_animal = df_neighborhood.groupby(['neighborhood', 'animal']).size().unstack(fill_value=0)

plt.figure(figsize=(10, 6), dpi=80)
plt.imshow(requests_per_neighborhood_animal, aspect='auto', cmap='coolwarm')
plt.xlabel('Animal')
plt.ylabel('Neighborhood')
plt.title('Number of Requests per Neighborhood and Animal')
plt.xticks(range(len(requests_per_neighborhood_animal.columns)), requests_per_neighborhood_animal.columns, rotation=90)
plt.yticks(range(len(requests_per_neighborhood_animal.index)), requests_per_neighborhood_animal.index)
plt.colorbar(label='Number of Requests')
plt.show()

# %%
# make the same plot as above but with log scale and put a box at the animal with the most requests for each neighborhood
plt.figure(figsize=(10, 6), dpi=80)
plt.imshow(np.log(requests_per_neighborhood_animal + 1), aspect='auto', cmap='coolwarm')
plt.xlabel('Animal')
plt.ylabel('Neighborhood')
plt.title('Log of Number of Requests per Neighborhood and Animal')
plt.xticks(range(len(requests_per_neighborhood_animal.columns)), requests_per_neighborhood_animal.columns, rotation=90)
plt.yticks(range(len(requests_per_neighborhood_animal.index)), requests_per_neighborhood_animal.index)
plt.colorbar(label='Log of Number of Requests')

for i, neighborhood in enumerate(requests_per_neighborhood_animal.index):
    most_requests = requests_per_neighborhood_animal.loc[neighborhood].idxmax()
    plt.text(len(requests_per_neighborhood_animal.columns) +1, i, most_requests, ha='center', va='center', color='black')

plt.show()

# %%
# # do the same but only for neighborhoods with more than 2000 requests
# requests_per_neighborhood = df_neighborhood['neighborhood'].value_counts()
# neighborhoods = requests_per_neighborhood[requests_per_neighborhood > 2000].index
# df_neighborhood = df_neighborhood[df_neighborhood['neighborhood'].isin(neighborhoods)]
# requests_per_neighborhood_animal = df_neighborhood.groupby(['neighborhood', 'animal']).size().unstack(fill_value=0)

# plt.figure(figsize=(10, 6), dpi=80)
# plt.imshow(np.log(requests_per_neighborhood_animal + 1), aspect='auto', cmap='coolwarm')
# plt.xlabel('Animal')
# plt.ylabel('Neighborhood')
# plt.title('Log of Number of Requests per Neighborhood and Animal')
# plt.xticks(range(len(requests_per_neighborhood_animal.columns)), requests_per_neighborhood_animal.columns, rotation=90)
# plt.yticks(range(len(requests_per_neighborhood_animal.index)), requests_per_neighborhood_animal.index)
# plt.colorbar(label='Log of Number of Requests')

# for i, neighborhood in enumerate(requests_per_neighborhood_animal.index):
#     most_requests = requests_per_neighborhood_animal.loc[neighborhood].idxmax()
#     plt.text(len(requests_per_neighborhood_animal.columns) +1, i, most_requests, ha='center', va='center', color='black')

# plt.show()

# %%
# for every neighborhood, print the most common animal
most_common_animal_per_neighborhood = requests_per_neighborhood_animal.idxmax(axis=1)
for neighborhood, animal in most_common_animal_per_neighborhood.items():
    print(f'{neighborhood}: \t{animal}')
# Out:
# Allston: 	Dogs
# Allston / Brighton: 	Dogs
# Back Bay: 	Birds
# Beacon Hill: 	Dogs
# Boston: 	Birds
# Brighton: 	Dogs
# Charlestown: 	Dogs
# Chestnut Hill: 	Cats
# Dorchester: 	Dogs
# Downtown / Financial District: 	Birds
# E. Boston: 	Dogs
# Fenway / Kenmore / Audubon Circle / Longwood: 	Birds
# Greater Mattapan: 	Dogs
# Hyde Park: 	Dogs
# Jamaica Plain: 	Dogs
# Mattapan: 	Dogs
# Mission Hill: 	Dogs
# Roslindale: 	Dogs
# Roxbury: 	Dogs
# S. Boston: 	Dogs
# S. Boston / S. Boston Waterfront: 	Birds
# S. End: 	Dogs
# W. Roxbury: 	Dogs

# %%
# print number ofo ONTIME and LATE
print(df_neighborhood['on_time'].value_counts())
# Out:
# on_time
# ONTIME     79523
# OVERDUE     3495
# Name: count, dtype: int64

# %%
# drop requests that do not have open_dt or closed_dt
df_neighborhood = df_neighborhood.dropna(subset=['open_dt', 'closed_dt'])
df_neighborhood['open_dt'] = pd.to_datetime(df_neighborhood['open_dt'])
df_neighborhood['closed_dt'] = pd.to_datetime(df_neighborhood['closed_dt'])
df_neighborhood['resolution_hours'] = (df_neighborhood['closed_dt'] - df_neighborhood['open_dt']).dt.total_seconds() / 3600

#new column for resolution hours for ONTIME
df_neighborhood['resolution_hours_ontime'] = df_neighborhood['resolution_hours'][df_neighborhood['on_time'] == 'ONTIME']

#new column for resolution hours for LATE
df_neighborhood['resolution_hours_late'] = df_neighborhood['resolution_hours'][df_neighborhood['on_time'] == 'OVERDUE']
# drop requests with nan neighborhood or " "
# df_neighborhood = df_neighborhood.dropna(subset=['neighborhood'])
# df_neighborhood = df_neighborhood[df_neighborhood['neighborhood'] != ' ']

# %%
# plot the avg resolution time for ONTIME for every neighborhood sorted by avg resolution time in reverse order
avg_resolution_time_ontime = df_neighborhood.groupby('neighborhood')['resolution_hours_ontime'].mean().sort_values(ascending=False)
plt.figure(figsize=(10, 6), dpi=80)
plt.bar(avg_resolution_time_ontime.index, avg_resolution_time_ontime.values, color='b', alpha=0.7)
plt.xlabel('Neighborhood')
plt.ylabel('Average Resolution Time (hours)')
plt.title('Average Resolution Time for ONTIME Requests per Neighborhood')
plt.xticks(rotation=90)
plt.show()

# %%
# for the request that are LATE and outside of the 90 percentile, print the number of days
resolution_hours_late = df_neighborhood['resolution_hours_late']
threshold = resolution_hours_late.quantile(0.83)
# print(f'90th percentile: {threshold}')
print(f'Number of LATE requests outside of the 90th percentile: {len(resolution_hours_late[resolution_hours_late > threshold])}')
print(f'Number of days for LATE requests outside of the 90th percentile: {resolution_hours_late[resolution_hours_late > threshold].apply(lambda x: x // 24).value_counts()}')
# Out:
# Number of LATE requests outside of the 90th percentile: 216
# Number of days for LATE requests outside of the 90th percentile: resolution_hours_late
# 397.0     4
# 387.0     3
# 1102.0    3
# 1848.0    3
# 411.0     3
#          ..
# 1830.0    1
# 1824.0    1
# 1822.0    1
# 1821.0    1
# 336.0     1
# Name: count, Length: 183, dtype: int64

# %%
# drop all requests that are LATE and outside of the 83 percentile
df_neighborhood = df_neighborhood[~((df_neighborhood['on_time'] == 'OVERDUE') & (df_neighborhood['resolution_hours'] > threshold))]

# %%
# for all the requests that are late, plot the number of days, with no threshold
plt.figure(figsize=(10, 6), dpi=80)
plt.hist(resolution_hours_late.apply(lambda x: x // 24), bins=range(int(resolution_hours_late.max() // 24) + 1))
plt.xlabel('Number of Days')
plt.ylabel('Number of Requests')
plt.title('Number of Days for LATE Requests')
plt.show()

# %%
# do the same for LATE
avg_resolution_time_late = df_neighborhood.groupby('neighborhood')['resolution_hours_late'].mean().sort_values(ascending=False)
plt.figure(figsize=(10, 6), dpi=80)
plt.bar(avg_resolution_time_late.index, avg_resolution_time_late.values, color='b', alpha=0.7)
plt.xlabel('Neighborhood')
plt.ylabel('Average Resolution Time (hours)')
plt.title('Average Resolution Time for LATE Requests per Neighborhood')
plt.xticks(rotation=90)
plt.show()

# %%
df_neighborhood['resolution_days'] = (df_neighborhood['closed_dt'] - df_neighborhood['open_dt']).dt.days
df_neighborhood['resolution_days_ontime'] = df_neighborhood['resolution_days'][df_neighborhood['on_time'] == 'ONTIME']
df_neighborhood['resolution_days_late'] = df_neighborhood['resolution_days'][df_neighborhood['on_time'] == 'OVERDUE']

# %%
# do the same as above but with days instead of hours
avg_resolution_time_ontime = df_neighborhood.groupby('neighborhood')['resolution_days_ontime'].mean().sort_values(ascending=False)
plt.figure(figsize=(10, 6), dpi=80)
plt.bar(avg_resolution_time_ontime.index, avg_resolution_time_ontime.values, color='b', alpha=0.7)
plt.xlabel('Neighborhood')
plt.ylabel('Average Resolution Time (days)')
plt.title('Average Resolution Time for ONTIME Requests per Neighborhood')
plt.xticks(rotation=90)
plt.show()

# %%
# do the same for LATE
avg_resolution_time_late = df_neighborhood.groupby('neighborhood')['resolution_days_late'].mean().sort_values(ascending=False)
plt.figure(figsize=(10, 6), dpi=80)
plt.bar(avg_resolution_time_late.index, avg_resolution_time_late.values, color='b', alpha=0.7)
plt.xlabel('Neighborhood')
plt.ylabel('Average Resolution Time (days)')
plt.title('Average Resolution Time for LATE Requests per Neighborhood')
plt.xticks(rotation=90)
plt.show()

# %%
# average resolution time for ONTIME for each animal
avg_resolution_time_ontime_animal = df_neighborhood.groupby('animal')['resolution_hours_ontime'].mean().sort_values(ascending=False)
plt.figure(figsize=(10, 6), dpi=80)
plt.bar(avg_resolution_time_ontime_animal.index, avg_resolution_time_ontime_animal.values, color='b', alpha=0.7)
plt.xlabel('Animal')
plt.ylabel('Average Resolution Time (hours)')
plt.title('Average Resolution Time for ONTIME Requests per Animal')
plt.xticks(rotation=90)
plt.show()

# %%
# for each animal, print the average resolution time for LATE requests if the time is not nan or ' '
avg_resolution_time_late_animal = df_neighborhood.groupby('animal')['resolution_hours_late'].mean().dropna().sort_values(ascending=False)
plt.figure(figsize=(10, 6), dpi=80)
plt.bar(avg_resolution_time_late_animal.index, avg_resolution_time_late_animal.values, color='b', alpha=0.7)
plt.xlabel('Animal')
plt.ylabel('Average Resolution Time (hours)')
plt.title('Average Resolution Time for LATE Requests per Animal')
plt.xticks(rotation=90)
plt.show()
